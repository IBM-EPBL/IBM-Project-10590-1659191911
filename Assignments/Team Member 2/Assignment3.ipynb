# %% [markdown]
# <center><b><h1>Assignment 3<h1></b></center>
# <b>Student Name:</b>Premnath S<br>
# <b>Student Roll No:</b> 737819CSR148

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#
# Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

# %% [markdown]
# **What is 7 to the power of 4?**

# %%
7**4
# Out:
# 2401

# %% [markdown]
# **Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list.**

# %%
s = "Hi there Sam!"

# %%
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %% [markdown]
# **Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# **Use .format() to print the following string:**
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
print("The diameter of {} is {} kilometers".format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers

# %% [markdown]
# **Given this nested list, use indexing to grab the word "hello"**

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
lst[3][1][2]
# Out:
# ['hello']

# %% [markdown]
# **Given this nest dictionary grab the word "hello". Be prepared, this will be annoying/tricky**

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# **What is the main difference between a tuple and a list?**

# %%
print("List is mutable but Tuple is immutable")
# Out:
# List is mutable but Tuple is immutable

# %% [markdown]
# **Create a function that grabs the email website domain from a string in the form:**
#
#     user@domain.com
#
# **So for example, passing "user@domain.com" would return: domain.com**

# %%
def domainName(mail):
  domain = mail.split('@',1)[1]
  return domain

# %%
domainName("user@domain.com")
# Out:
# 'domain.com'

# %% [markdown]
# **Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization.**

# %%
def wordDog(inputString):
  return "dog" in inputString

# %%
s = input("Enter a string to test: ")
wordDog(s)
# Out:
# Enter a string to test: dog is a lovable pet, pet dogs are cute
# True

# %% [markdown]
# **Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases.**

# %%
def numberOfDog(inputString):
  return inputString.count('dog')

# %%
s = input("Enter a string to count: ")
numberOfDog(s)
# Out:
# Enter a string to count: dog
# 1

# %% [markdown]
# ### Problem
# **You are driving a little too fast, and a police officer stops you. Write a function to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket".
#   If your speed is 60 or less, the result is "No Ticket". If speed is between 61 and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all cases.**

# %%
def speedLimit(speed,isBirthday):
  if isBirthday:
    speed -= 5
  if speed<61:
    return "No Ticket"
  elif speed<81:
    return "Small Ticket"
  else:
    return "Big Ticket"

# %%
speedLimit(82,False)
# Out:
# 'Big Ticket'

# %%
speedLimit(61,True)
# Out:
# 'No Ticket'

# %% [markdown]
# **Create an employee list with basic salary values(at least 5 values for 5 employees)  and using a for loop retreive each employee salary and calculate total salary expenditure.**

# %%
employee_Salary = [30000, 20000, 40000, 50000, 100000, 280000]
totalSalary = 0
for salary in employee_Salary:
  totalSalary += salary
print(totalSalary)
# Out:
# 520000

# %% [markdown]
# **Create two dictionaries in Python:**
#
# **First one to contain fields as Empid,  Empname,  Basicpay**
#
# **Second dictionary to contain fields as DeptName,  DeptId.**
#
# **Combine both dictionaries.**

# %%
def mergeDict(d1,d2):
  res = {**d1, **d2}
  return res

# %%
employee = {
    "Empid" : 148,
    "Empname" : "premnath",
    "Basicpay" : 2500000
}
department = {
    "DeptName": "Web Developer",
    "DeptId" : "SD3"
}

empDetails = mergeDict(employee,department)
print(empDetails)
# Out:
# {'Empid': 148, 'Empname': 'premnath', 'Basicpay': 2500000, 'DeptName': 'Web Developer', 'DeptId': 'SD3'}
